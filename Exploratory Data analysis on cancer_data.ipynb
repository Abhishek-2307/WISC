# %% [markdown]
# ## University of wisconson data set on breast cancer

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Importing the Dataset in notebook

# %%
df = pd.read_csv('wisc_bc_data.csv')
df.head() ## will show only first 5 rows
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.tail() ## will show last five rows in dataset
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 564  926424         M        21.56         22.39          142.00     1479.0
# 565  926682         M        20.13         28.25          131.20     1261.0
# 566  926954         M        16.60         28.08          108.30      858.1
# 567  927241         M        20.60         29.33          140.10     1265.0
# 568   92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
# ...

# %%
df.columns   ## will show all the columns labels present in the dataset
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %% [markdown]
# ## Wrangling (Assessing and Building Intution)

# %%
## This returns a tuple of the dimesions of the dataframe
df.shape
# Out:
# (569, 32)

# %%
##This returns the datatypes of the columns
df.dtypes
# Out:
# id                           int64
# diagnosis                   object
# radius_mean                float64
# texture_mean               float64
# perimeter_mean             float64
# area_mean                  float64
# smoothness_mean            float64
# compactness_mean           float64
# concavity_mean             float64
# concave points_mean        float64
# symmetry_mean              float64
# fractal_dimension_mean     float64
# radius_se                  float64
# texture_se                 float64
# perimeter_se               float64
# area_se                    float64
# smoothness_se              float64
# compactness_se             float64
# concavity_se               float64
# concave points_se          float64
# symmetry_se                float64
# fractal_dimension_se       float64
# radius_worst               float64
# texture_worst              float64
# perimeter_worst            float64
# area_worst                 float64
# smoothness_worst           float64
# ...

# %%
# although the datatype for diagnosis appears to be object, further
# investigation shows it's a string
type(df['diagnosis'][0])
# Out:
# str

# %%
# this displays a concise summary of the dataframe,
# including the number of non-null values in each column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
# id                         569 non-null int64
# diagnosis                  569 non-null object
# radius_mean                569 non-null float64
# texture_mean               569 non-null float64
# perimeter_mean             569 non-null float64
# area_mean                  569 non-null float64
# smoothness_mean            569 non-null float64
# compactness_mean           569 non-null float64
# concavity_mean             569 non-null float64
# concave points_mean        569 non-null float64
# symmetry_mean              569 non-null float64
# fractal_dimension_mean     569 non-null float64
# radius_se                  569 non-null float64
# texture_se                 569 non-null float64
# perimeter_se               569 non-null float64
# area_se                    569 non-null float64
# smoothness_se              569 non-null float64
# ...

# %%
# This returns the number of unique values in each column
df.nunique()
# Out:
# id                         569
# diagnosis                    2
# radius_mean                456
# texture_mean               479
# perimeter_mean             522
# area_mean                  539
# smoothness_mean            474
# compactness_mean           537
# concavity_mean             537
# concave points_mean        542
# symmetry_mean              432
# fractal_dimension_mean     499
# radius_se                  540
# texture_se                 519
# perimeter_se               533
# area_se                    528
# smoothness_se              547
# compactness_se             541
# concavity_se               533
# concave points_se          507
# symmetry_se                498
# fractal_dimension_se       545
# radius_worst               457
# texture_worst              511
# perimeter_worst            514
# area_worst                 544
# smoothness_worst           411
# compactness_worst          529
# concavity_worst            539
# concave points_worst       492
# ...

# %%
# This returns useful descriptive statistics for each column of data
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
# View the index number and label for each column
for i, v in enumerate(df.columns):
    print(i, v)
# Out:
# 0 id
# 1 diagnosis
# 2 radius_mean
# 3 texture_mean
# 4 perimeter_mean
# 5 area_mean
# 6 smoothness_mean
# 7 compactness_mean
# 8 concavity_mean
# 9 concave points_mean
# 10 symmetry_mean
# 11 fractal_dimension_mean
# 12 radius_se
# 13 texture_se
# 14 perimeter_se
# 15 area_se
# 16 smoothness_se
# 17 compactness_se
# 18 concavity_se
# 19 concave points_se
# 20 symmetry_se
# 21 fractal_dimension_se
# 22 radius_worst
# 23 texture_worst
# 24 perimeter_worst
# 25 area_worst
# 26 smoothness_worst
# 27 compactness_worst
# 28 concavity_worst
# 29 concave points_worst
# 30 symmetry_worst
# 31 fractal_dimension_worst

# %%
# select all the columns from 'id' to hte last mean column
df_means = df.loc[:,'id':'fractal_dimension_mean']
df_means.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  fractal_dimension_mean
# ...

# %%
df_means.to_csv('cancer_data_means.csv', index=False)

# %% [markdown]
# ## Cleaning the data

# %%
df1 = pd.read_csv('cancer_data_means.csv')
# check whihc columns have missing values with info
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 12 columns):
# id                        569 non-null int64
# diagnosis                 569 non-null object
# radius_mean               569 non-null float64
# texture_mean              569 non-null float64
# perimeter_mean            569 non-null float64
# area_mean                 569 non-null float64
# smoothness_mean           569 non-null float64
# compactness_mean          569 non-null float64
# concavity_mean            569 non-null float64
# concave points_mean       569 non-null float64
# symmetry_mean             569 non-null float64
# fractal_dimension_mean    569 non-null float64
# dtypes: float64(10), int64(1), object(1)
# memory usage: 53.4+ KB

# %%
sum(df.duplicated())
# Out:
# 0

# %%
## remove "_mean" from columns names
new_labels = []
for col in df1.columns:
    if '_mean' in col:
        new_labels.append(col[:-5])  # exclude last 6 characters
    else:
        new_labels.append(col)
        
# new labels for our columns
new_labels
# Out:
# ['id',
#  'diagnosis',
#  'radius',
#  'texture',
#  'perimeter',
#  'area',
#  'smoothness',
#  'compactness',
#  'concavity',
#  'concave points',
#  'symmetry',
#  'fractal_dimension']

# %%
# assign new labels to columns in dataframe
df1.columns = new_labels

# display first few rows of dataframe  to confirm changes
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df1.to_csv('cancer_data_edit.csv', index=False)

# %% [markdown]
# ## Exploring Data with visuals

# %%
df2 = pd.read_csv('cancer_data_edit.csv')

df2.head()
# Out:
#          id diagnosis  radius  texture  perimeter    area  smoothness  \
# 0    842302         M   17.99    10.38     122.80  1001.0     0.11840
# 1    842517         M   20.57    17.77     132.90  1326.0     0.08474
# 2  84300903         M   19.69    21.25     130.00  1203.0     0.10960
# 3  84348301         M   11.42    20.38      77.58   386.1     0.14250
# 4  84358402         M   20.29    14.34     135.10  1297.0     0.10030
#
#    compactness  concavity  concave points  symmetry  fractal_dimension
# 0      0.27760     0.3001         0.14710    0.2419            0.07871
# 1      0.07864     0.0869         0.07017    0.1812            0.05667
# 2      0.15990     0.1974         0.12790    0.2069            0.05999
# 3      0.28390     0.2414         0.10520    0.2597            0.09744
# 4      0.13280     0.1980         0.10430    0.1809            0.05883

# %%
pd.plotting.scatter_matrix(df2, figsize=(15, 15));

# %%
df2.plot(x='compactness', y ='concavity', kind='scatter');

# %%
df2['concave points'].plot(kind='box');

# %% [markdown]
# ## conclusions based on descriptive statistics

# %%
# creating a new dataframe that only contains malignent tumor
df_m = df2[df2['diagnosis'] == 'M']
df_m.head()
# Out:
#          id diagnosis  radius  texture  perimeter    area  smoothness  \
# 0    842302         M   17.99    10.38     122.80  1001.0     0.11840
# 1    842517         M   20.57    17.77     132.90  1326.0     0.08474
# 2  84300903         M   19.69    21.25     130.00  1203.0     0.10960
# 3  84348301         M   11.42    20.38      77.58   386.1     0.14250
# 4  84358402         M   20.29    14.34     135.10  1297.0     0.10030
#
#    compactness  concavity  concave points  symmetry  fractal_dimension
# 0      0.27760     0.3001         0.14710    0.2419            0.07871
# 1      0.07864     0.0869         0.07017    0.1812            0.05667
# 2      0.15990     0.1974         0.12790    0.2069            0.05999
# 3      0.28390     0.2414         0.10520    0.2597            0.09744
# 4      0.13280     0.1980         0.10430    0.1809            0.05883

# %%
mask = df2['diagnosis'] == 'M'
df_m = df2[mask]
df_m
# Out:
#             id diagnosis  radius  texture  perimeter    area  smoothness  \
# 0       842302         M   17.99    10.38     122.80  1001.0     0.11840
# 1       842517         M   20.57    17.77     132.90  1326.0     0.08474
# 2     84300903         M   19.69    21.25     130.00  1203.0     0.10960
# 3     84348301         M   11.42    20.38      77.58   386.1     0.14250
# 4     84358402         M   20.29    14.34     135.10  1297.0     0.10030
# 5       843786         M   12.45    15.70      82.57   477.1     0.12780
# 6       844359         M   18.25    19.98     119.60  1040.0     0.09463
# 7     84458202         M   13.71    20.83      90.20   577.9     0.11890
# 8       844981         M   13.00    21.82      87.50   519.8     0.12730
# 9     84501001         M   12.46    24.04      83.97   475.9     0.11860
# 10      845636         M   16.02    23.24     102.70   797.8     0.08206
# 11    84610002         M   15.78    17.89     103.60   781.0     0.09710
# ...

# %%
df_m['area'].describe()
# Out:
# count     212.000000
# mean      978.376415
# std       367.937978
# min       361.600000
# 25%       705.300000
# 50%       932.000000
# 75%      1203.750000
# max      2501.000000
# Name: area, dtype: float64

# %%
df_b = df2[df2['diagnosis'] == 'B']
df_b['area'].describe()
# Out:
# count    357.000000
# mean     462.790196
# std      134.287118
# min      143.500000
# 25%      378.200000
# 50%      458.400000
# 75%      551.100000
# max      992.100000
# Name: area, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(8, 6))
plt.hist(df_b['area'], alpha=0.5, label='benign')
plt.hist(df_m['area'], alpha=0.5, label='malignant')
plt.title('Distribution of Benign and Maligmnant Tumor Areas')
plt.xlabel('Area')
plt.ylabel('count')
plt.legend(loc='upper right')
plt.show()
